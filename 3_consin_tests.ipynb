# %%
import numpy as np
import pandas as pd

# %%
animes_rated_by_users = pd.read_parquet('./recommendation_cosine_matrix.parquet')

# %%
animes_rated_by_users.head()
# Out:
# title                                         "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi  \
# title
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                      1.000000
# "Bungaku Shoujo" Memoire                                                       0.686575
# "Bungaku Shoujo" Movie                                                         0.560973
# "Eikou Naki Tensai-tachi" Kara no Monogatari                                   0.000000
# "Eiyuu" Kaitai                                                                 0.089963
#
# title                                         "Bungaku Shoujo" Memoire  \
# title
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                     0.686575
# "Bungaku Shoujo" Memoire                                      1.000000
# "Bungaku Shoujo" Movie                                        0.644669
# "Eikou Naki Tensai-tachi" Kara no Monogatari                  0.030122
# ...

# %%
cosine_df = animes_rated_by_users['Boku no Hero Academia'].sort_values(ascending=False)
cosine_df.columns = ['Recommendations']
cosine_df.head(20)
# Out:
# title
# Boku no Hero Academia                     1.000000
# Boku no Hero Academia 2nd Season          0.829713
# One Punch Man                             0.720767
# Re:Zero kara Hajimeru Isekai Seikatsu     0.663557
# Mob Psycho 100                            0.638851
# Boku dake ga Inai Machi                   0.637113
# Nanatsu no Taizai                         0.628415
# Shingeki no Kyojin Season 2               0.625139
# Kono Subarashii Sekai ni Shukufuku wo!    0.616624
# Shokugeki no Souma                        0.614844
# No Game No Life                           0.614704
# Tokyo Ghoul                               0.613423
# Shingeki no Kyojin                        0.609565
# Noragami                                  0.600411
# Kimi no Na wa.                            0.593344
# Ansatsu Kyoushitsu                        0.592627
# Kiseijuu: Sei no Kakuritsu                0.589497
# Shokugeki no Souma: Ni no Sara            0.586925
# ...
